# %%
import pprint
import wandb
import sys  
sys.path.insert(0, '../')

from learning_to_score.train import train

# %%
sweep_config = {
    'method': 'grid'
    }

parameters_dict = {
    'scorer_last_activation_function': {
        'values': ['softmax', 'argmax']
    }
}



parameters_dict.update({
    'input_dim': {'value': 200},
    'num_of_clusters': {'value': 10},
    'number_of_samples_in_cluster': {'value': 1000},
    'cluster_dim_mean': {'value': 3},
    'mean': {'value': 0},
    'variance': {'value': 2},
    'side_information_type': {'value': "merged_clusters"},
    'triplet_loss_margin': {'value': 1},
    'alpha': {'value': 1},
    'beta': {'value': 1},
    'gamma': {'value': 1},
    'encoder_hidden_dims': {'value': [100, 50]},
    'latent_dim': {'value': 20},
    'epochs': {'value': 100},
    }
)


sweep_config['parameters'] = parameters_dict

pprint.pprint(sweep_config)

sweep_id = wandb.sweep(sweep_config, project="LearningToScore-research")

wandb.agent(sweep_id, train)

# %%
sweep_config = {
    'method': 'grid'
    }

parameters_dict = {
    'gamma': {
        'values': [0,0.001,0.01,0.1,1,10,100]
    }
}



parameters_dict.update({
    'input_dim': {'value': 200},
    'num_of_clusters': {'value': 10},
    'number_of_samples_in_cluster': {'value': 1000},
    'cluster_dim_mean': {'value': 3},
    'mean': {'value': 0},
    'variance': {'value': 2},
    'side_information_type': {'value': "merged_clusters"},
    'triplet_loss_margin': {'value': 1},
    'alpha': {'value': 1},
    'beta': {'value': 1},
    'encoder_hidden_dims': {'value': [100, 50]},
    'latent_dim': {'value': 20},
    'epochs': {'value': 100},
    }
)


sweep_config['parameters'] = parameters_dict

pprint.pprint(sweep_config)

sweep_id = wandb.sweep(sweep_config, project="LearningToScore-research")

wandb.agent(sweep_id, train)

# %%
sweep_config = {
    'method': 'grid'
    }

parameters_dict = {
    'gamma': {
        'values': [0,0.001,0.01,0.1,1,10,100]
    }
}



parameters_dict.update({
    'input_dim': {'value': 200},
    'num_of_clusters': {'value': 10},
    'number_of_samples_in_cluster': {'value': 1000},
    'cluster_dim_mean': {'value': 3},
    'mean': {'value': 0},
    'variance': {'value': 2},
    'side_information_type': {'value': "pure"},
    'triplet_loss_margin': {'value': 1},
    'alpha': {'value': 1},
    'beta': {'value': 1},
    'encoder_hidden_dims': {'value': [100, 50]},
    'latent_dim': {'value': 20},
    'epochs': {'value': 100},
    }
)


sweep_config['parameters'] = parameters_dict

pprint.pprint(sweep_config)

sweep_id = wandb.sweep(sweep_config, project="LearningToScore-research")

# wandb.agent(sweep_id, train)
